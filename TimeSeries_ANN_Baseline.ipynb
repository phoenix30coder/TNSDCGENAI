# %% [markdown]
# # Imports

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# general array and data handling
import numpy as np
import pandas as pd

# tensor operations and neural networks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, LeakyReLU, Flatten

# Ploting
import matplotlib.pyplot as plt

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# # Data Loading

# %%
data_names = ["S&P500","SSE","IBM","MSFT","PAICC"]
data_name = data_names[0]
data_path="datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path)
# Out:
# datasets/S&P500.csv

# %%
dataframe.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5031.000000  5031.000000  5031.000000  5031.000000  5031.000000
# mean   1495.419580  1504.207347  1485.896934  1495.566086  1495.566086
# std     499.462791   499.894439   498.801221   499.378368   499.378368
# min     679.280029   695.270020   666.789978   676.530029   676.530029
# 25%    1151.739990  1159.934998  1142.179993  1151.629944  1151.629944
# 50%    1334.369995  1343.319946  1325.689941  1334.219971  1334.219971
# 75%    1806.269959  1810.450012  1800.674988  1805.450012  1805.450012
# max    2936.760010  2940.909912  2927.110107  2930.750000  2930.750000
#
#              Volume
# count  5.031000e+03
# mean   2.954812e+09
# std    1.545804e+09
# min    3.121200e+08
# 25%    1.488865e+09
# 50%    3.078530e+09
# 75%    3.886925e+09
# max    1.145623e+10

# %%
dataframe.shape
# Out:
# (5031, 7)

# %%
def add_Ma(dataframe):
  Ma_window=5
  for i in range(0,dataframe.shape[0]-Ma_window):
    dataframe.loc[dataframe.index[i+Ma_window],'Ma'] = np.round(((dataframe.iloc[i,4]+ dataframe.iloc[i+1,4] +dataframe.iloc[i+2,4] + dataframe.iloc[i+3,4]+ dataframe.iloc[i+4,4])/5),6)
  return dataframe[5:-5]

dataframe=add_Ma(dataframe)
dataframe.head()
# Out:
#          Date         Open         High          Low        Close  \
# 5  1999-01-11  1275.089966  1276.219971  1253.339966  1263.880005
# 6  1999-01-12  1263.880005  1264.449951  1238.290039  1239.510010
# 7  1999-01-13  1239.510010  1247.750000  1205.459961  1234.400024
# 8  1999-01-14  1234.400024  1236.810059  1209.540039  1212.189941
# 9  1999-01-15  1212.189941  1243.260010  1212.189941  1243.260010
#
#      Adj Close     Volume           Ma
# 5  1263.880005  818000000  1258.007983
# 6  1239.510010  800200000  1265.163989
# 7  1234.400024  931500000  1264.109985
# 8  1212.189941  797200000  1256.521997
# 9  1243.260010  798100000  1245.013989

# %%
def plot_dataframe(dataframe):

  for column_name in dataframe.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(dataframe[column_name])

plot_dataframe(dataframe)

# %% [markdown]
# # Preprocessing

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    # shape : (n_batch, n_sequence, n_features)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    std[std==0] = 1
    samples = (samples - mean[:,None,:])/std[:,None,:] #standarize along each feature
    targets = (targets - mean[:,3:4])/std[:,3:4] # The close value is our target
    return samples, targets

# %%
# TimeseriesGenerator Check

data = np.array([[i, i**2,i**3,i**4] for i in range(11)])
targets = np.array([[i**4] for i in range(11)])

print(targets.shape)

mean = data[:-1].mean(axis=0)[None,:]
std = data[:-1].std(axis=0)[None,:]

data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=10, sampling_rate=1,
                               batch_size=2)
batch_0 = data_gen[0]
x, y = batch_0

print(np.array(x*std+mean,dtype = int))
print(y*std[..., 3]+mean[..., 3])
# Out:
# (11, 1)
# [[[   0    0    0    0]
#   [   1    1    1    1]
#   [   2    4    8   16]
#   [   3    9   27   81]
#   [   4   16   64  256]
#   [   5   25  125  625]
#   [   6   36  216 1296]
#   [   7   49  343 2401]
#   [   8   64  512 4096]
#   [   9   81  729 6561]]]
# [[10000.]]

# %%
data.shape
# Out:
# (11, 4)

# %%
# Generarate 5 days sequences from all data
# TODO: How to deal with weekend lack of information?

n_sequence = 5
n_batch = 128
n_features = 7

def get_gen_train_test(dataframe):
  data = dataframe.drop(columns='Date').to_numpy()
  targets = data[:,3, None] #add none to have same number of dimensions as data
  #targets = data
  n_samples = data.shape[0]

  train_test_split=int(n_samples*0.9)

  data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
  data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)
  
  return data_gen_train, data_gen_test

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

# %%
data_gen_train[0]
# Out:
# (array([[[-0.26073367, -1.26118546, -0.3729715 , ..., -0.53019771,
#           -0.69359118, -0.83723202],
#          [-1.33966667,  0.72561083, -0.04209038, ...,  0.9287158 ,
#            1.45594588, -1.22787831],
#          [ 0.90601525,  1.38427897,  1.67055862, ...,  1.22745449,
#           -1.15111229, -0.14493499],
#          [ 1.36585888,  0.12633938,  0.17231992, ..., -0.09610435,
#           -0.51220707,  1.51011591],
#          [-0.67147379, -0.97504372, -1.42781666, ..., -1.52986823,
#            0.90096465,  0.69992941]],
#
#         [[ 1.79330256,  1.39168167,  0.96927175, ...,  0.19955741,
#           -0.9860466 ,  1.42413739],
#          [ 0.09237532,  0.47259265,  0.85995294, ...,  0.51884509,
#           -0.24284604,  0.63299901],
#          [-0.0822425 , -1.21239687, -1.51856988, ..., -1.12183638,
#            1.82579869,  0.1288762 ],
#          [-1.16871889, -1.08669494, -0.85055597, ..., -1.09270963,
#            0.17958914, -0.80559516],
#          [-0.6347165 ,  0.43481749,  0.53990116, ...,  1.49614351,
#           -0.7764952 , -1.38041744]],
#
#         [[-1.14578752, -0.7170085 , -1.05815871, ..., -1.44213932,
#            0.0813816 , -1.37890818],
#          [-0.82331217, -1.2336376 , -0.95463152, ..., -0.95645607,
#           -1.61914141, -0.6074685 ],
#          [-0.39208092,  0.02442986, -0.2193064 , ...,  0.60710298,
#           -0.2694564 , -0.14889814],
#          [ 0.99618094,  0.2187004 ,  0.65249907, ...,  1.02249281,
#            0.3264876 ,  0.60518508],
#          [ 1.36499967,  1.70751585,  1.57959757, ...,  0.7689996 ,
#            1.48072861,  1.53008974]],
#
#         ...,
#
#         [[-0.49617509, -0.74424347, -0.14958122, ..., -0.82073107,
#           -0.63096458, -1.11155263],
#          [-0.85720493, -0.7900123 , -0.03762061, ..., -0.81392751,
#            0.52796995, -0.90773599],
#          [-1.02903532, -0.45908031,  0.07431094, ...,  0.73747443,
#           -0.44718961, -0.14061448],
#          [ 0.94407929,  1.89792636,  1.63193201, ...,  1.61426447,
#            1.68431204,  0.53768638],
#          [ 1.43833605,  0.09540973, -1.51904112, ..., -0.71708032,
#           -1.13412779,  1.62221671]],
#
#         [[ 1.30818773,  0.93452942,  0.79215162, ...,  0.10202759,
#            0.16051734,  0.02761037],
#          [-0.26286824,  1.15510281,  0.41167692, ...,  1.3094637 ,
#            1.74408422, -1.38061369],
#          [ 0.52420762,  0.15237102,  1.15034528, ...,  0.76551795,
#           -0.99183328,  0.52463642],
#          [ 0.14072114, -0.7633104 , -0.94400273, ..., -1.48799983,
#            0.05941535,  1.52656923],
#          [-1.71024825, -1.47869285, -1.41017109, ..., -0.68900941,
#           -0.97218362, -0.69820233]],
#
#         [[-1.62475329, -0.30594555, -1.3314784 , ...,  0.09451669,
#            1.78649993, -1.37570628],
#          [ 0.39129568, -0.37465845,  0.31318134, ..., -0.7725674 ,
#            0.32783394, -0.69548421],
#          [-0.3676129 , -1.5083284 , -0.99123756, ..., -0.77738286,
#           -0.4170103 , -0.09403345],
#          [ 0.17196075,  1.31271066,  1.25717187, ...,  1.89620698,
#           -0.64058533,  0.71464846],
#          [ 1.42910976,  0.87622174,  0.75236275, ..., -0.4407734 ,
#           -1.05673826,  1.45057549]]]),
#  array([[-0.53792788],
#         [ 3.35688171],
#         [-0.49100996],
#         [ 0.63503683],
#         [-1.09821973],
#         [-6.15450347],
#         [-1.55441878],
#         [ 1.54601868],
#         [ 0.0962574 ],
#         [ 1.50156439],
#         [-1.22367539],
#         [ 0.21141029],
#         [ 0.71833402],
#         [ 0.4058818 ],
#         [-0.39376219],
#         [-1.39633528],
#         [ 5.86745677],
#         [ 0.37245585],
#         [ 0.05314263],
#         [ 1.99578735],
#         [-1.88430796],
#         [-2.14399112],
#         [ 4.35370935],
#         [ 1.33515525],
#         [-1.2634269 ],
#         [-1.7452508 ],
#         [ 2.24015181],
#         [ 0.24381453],
#         [ 1.50156439],
#         [-0.2696281 ],
#         [-1.4727137 ],
#         [-0.15567637],
#         [-0.92294277],
#         [ 0.70874109],
#         [-1.56864319],
#         [ 0.87445532],
#         [ 5.36689174],
#         [-0.70595752],
#         [-0.79705075],
#         [ 2.06252012],
#         [-0.04225441],
#         [ 2.24015181],
#         [-2.9637294 ],
#         [-0.95515399],
#         [ 0.09784779],
#         [ 3.98933451],
#         [ 6.12775525],
#         [-3.22564202],
#         [-0.8151701 ],
#         [-2.97381386],
#         [ 0.2722621 ],
#         [-0.49850541],
#         [-0.99384312],
#         [-1.83574793],
#         [-4.44319985],
#         [ 5.86745677],
#         [ 1.29149252],
#         [ 0.48181316],
#         [-0.74258483],
#         [-2.20591533],
#         [ 1.2536056 ],
#         [ 0.48981627],
#         [-0.65150937],
#         [ 0.27783564],
#         [ 0.55405469],
#         [ 1.98994697],
#         [-2.9637294 ],
#         [ 1.00684365],
#         [-2.52526691],
#         [-1.66252345],
#         [ 0.88816336],
#         [-1.80282718],
#         [ 1.2131607 ],
#         [ 2.56600999],
#         [ 1.00765345],
#         [ 2.5589894 ],
#         [-1.11975178],
#         [ 4.3639865 ],
#         [ 1.32384721],
#         [-0.95861194],
#         [-3.0046876 ],
#         [ 1.35773202],
#         [-3.11072915],
#         [ 0.44628404],
#         [ 1.45655143],
#         [ 1.37823074],
#         [-1.4264051 ],
#         [-0.4748914 ],
#         [ 1.24323404],
#         [ 1.69569532],
#         [-0.42986831],
#         [ 0.10430284],
#         [ 1.42388625],
#         [-0.62540155],
#         [ 0.54641299],
#         [ 6.95771248],
#         [ 0.73896554],
#         [-0.25378057],
#         [ 1.46817911],
#         [-1.88546009],
#         [-1.02329955],
#         [ 2.3170913 ],
#         [ 0.75103647],
#         [ 1.17741922],
#         [-4.43622044],
#         [-4.02396614],
#         [ 0.34223974],
#         [ 2.2052201 ],
#         [ 0.36973954],
#         [-7.14530465],
#         [-3.20055187],
#         [ 1.74008166],
#         [ 0.91086112],
#         [-1.78061116],
#         [-0.59814768],
#         [-3.15731002],
#         [ 1.16555386],
#         [ 1.92308398],
#         [ 0.99782164],
#         [-0.43952962],
#         [-2.46293103],
#         [ 2.68814427],
#         [-0.61471512],
#         [-1.1883537 ],
#         [-1.52481326],
#         [ 4.07137165],
#         [ 0.58618908],
#         [ 0.38194748]]))

# %%
# test on data

x_gen, y_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=1)[0]
print(x_gen)
print(y_gen)

x = data[None, :5,:]
mean = x.mean(axis=1)
std = x.std(axis=1)
x = (x - mean)/std
y = (data[5,3] - mean[...,3])/std[...,3]
print(x)
print(y)

assert (x_gen == x).all()
assert y_gen == y
# Out:
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [[5.69853465]]
# [[[-1.41421356 -1.01709526 -0.83189033 -0.72799757]
#   [-0.70710678 -0.84757938 -0.79029581 -0.71771512]
#   [ 0.         -0.33903175 -0.4991342  -0.56347834]
#   [ 0.70710678  0.50854763  0.29116162  0.10488101]
#   [ 1.41421356  1.69515876  1.83015873  1.90431003]]]
# [5.69853465]

# %% [markdown]
# # Baseline

# %%
# baseline: use previous day as estimation for the next
squared_error = 0
def mean_squared_error(X, lenght = 5):
  squared_error = 0
  for i in range(0, X.shape[0] - lenght):
    x = X[i:i+lenght]
    mean = x.mean()
    std = x.std()
    x = (x - mean)/std
    y = (X[i+lenght] - mean)/std
    squared_error += np.square(x[-1]-y)
  return squared_error/X.shape[0]

baseline_error = mean_squared_error(data[:,3])
baseline_error
# Out:
# 3.4528189810500125

# %%
data_gen = Standarized_TimeseriesGenerator(data, targets,
                               length=5, sampling_rate=1,
                               stride=1, batch_size=32)

# baseline: use previous day as estimation for the next
def mean_squared_error(dataset):
  mse=0
  for X_batch, y_batch in dataset:
    # X_batch.shape : (n_batch, n_sequence, n_features)
    #mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
    mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch))
  mse /= len(dataset)
  return mse

baseline_error = mean_squared_error(data_gen)
baseline_error
# Out:
# 6.330168131925023

# %% [markdown]
# # Utilities

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
def mse(y_true, y_pred):
  return tf.reduce_mean(tf.square(y_true-y_pred))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true-y_pred)))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:] > y_true[:-1],tf.float32)
    return tf.reduce_mean((y_true[1:]-y_true[:-1])*mask)


#class ar(tf.keras.metrics.Metric):
#  def __init__(self, name="ar", **kwargs):
#    super(ar, self).__init__(name=name, **kwargs)
#    self.y_old = self.add_weight(name='y_old', shape=n_batch, initializer='zeros', dtype=tf.float32)
#    self.y_true = self.add_weight(name='y_true', shape=n_batch, initializer='zeros', dtype=tf.float32)
#    self.y_pred = self.add_weight(name='y_pred', shape=n_batch, initializer='zeros', dtype=tf.float32)

#  def update_state(self, y_true, y_pred, sample_weight = None):
#    self.y_true = y_true[:,3]
#    self.y_pred = y_pred[:,3]
#    # shape y : (batch_size, n_features)
#    self.y_old = tf.stack([self.y_old[-1] , self.y_true[:-1]], 0)

#  def result(self):
#    mask = tf.cast(self.y_pred > self.y_old, tf.float32)
#    return tf.reduce_mean((self.y_true - self.y_old)*mask)

# %%
# Metrics not included in keras

# For some reason keras mape is different so it has to be customly defined.
# Paper definition isn't percentual, hence the difference. (x100)
#def mape(y_true, y_pred):
#    return tf.keras.backend.mean(tf.keras.backend.abs((y_true-y_pred)/y_true))
#    # ***The absolute is over the whole thing as y_true can be negative

#def rmse(y_true, y_pred):
#    return tf.sqrt(tf.keras.backend.mean(tf.square(y_true-y_pred)))

#def ar(y_true, y_pred):
#    N = tf.cast(tf.size(y_true), tf.float32)
#    return tf.keras.backend.sum(tf.keras.backend.maximum(y_true-y_pred, 0)) / (N-1)

# %% [markdown]
# # ANN

# %%
def make_ANN_model():

  inputs = Input(shape=(n_sequence, n_features,))
  inputs_flatten = Flatten()(inputs)
  ann_1 = Dense(units=1000, activation=None)(inputs_flatten)
  batch_norm1=tf.keras.layers.BatchNormalization()(ann_1)
  ann_1_LRelu = LeakyReLU(alpha=0.3)(ann_1) 
  ann_1_droput = Dropout(0.3)(ann_1_LRelu)
  ann_2 = Dense(units=100, activation=None)(ann_1_droput)
  batch_norm2=tf.keras.layers.BatchNormalization()(ann_2)
  ann_2_LRelu = LeakyReLU(alpha=0.3)(ann_2) 
  ann_2_droput = Dropout(0.3)(ann_2_LRelu)
  output_dense = Dense(1, activation=None)(ann_2_droput)
  output = LeakyReLU(alpha=0.3)(output_dense) 


  model = Model(inputs = inputs, outputs = output)
  #model.compile(loss=generator_loss)
  model.compile(loss='mse', metrics = [mse , mae, mape, rmse, ar])
  #model.compile(loss=None, metrics = [mse , mae, mape, rmse])
  model.summary()

  #return model, slice_model
  return model

  #history = model.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
   #                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))

# %%
#lstm = make_ANN_model()
#history = lstm.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
#                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))

# %% [markdown]
# # Visualization

# %%
metrics = ["loss", 'mse','mae','mape','rmse','ar']
def plot_history(history):
  #metrics = ["loss", 'mse','mae','mape','rmse','ar']
  #metrics = ["gen_loss","gen_slice_loss", 'mse','mae','mape','rmae','ar']
  for metric_name in metrics:  
    plt.figure()
    plt.title(metric_name)
    plt.plot(history.history[metric_name], label='train')
    plt.plot(history.history["val_"+metric_name], label='test')
    plt.legend()
  plt.show()

#plot_history(history)

# %%
def plot_frame(sequence, target, model):
  sequence, target = data_gen_test[0]
  y_pred = model.predict(sequence)
  y_true = target

  plt.figure()
  plt.title("closing price")
  plt.plot(y_true, label="true")
  plt.plot(y_pred, label="prediction")
  plt.legend()
  plt.show()

#plot_frame(*data_gen_test[0], lstm)

# %% [markdown]
# # Test on all datasets

# %%
results = np.zeros((5,6))

# %% [markdown]
# ## S&P500

# %%
data_name = data_names[0]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100,
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[0] = ann.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/S&P500.csv
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  flatten (Flatten)           (None, 35)                0
#
#  dense (Dense)               (None, 1000)              36000
#
#  leaky_re_lu (LeakyReLU)     (None, 1000)              0
#
#  dropout (Dropout)           (None, 1000)              0
#
#  dense_1 (Dense)             (None, 100)               100100
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 100)               0
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1)                 0
#
# =================================================================
# Total params: 136201 (532.04 KB)
# Trainable params: 136201 (532.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 13ms/step - loss: 4.0932 - mse: 4.0932 - mae: 1.3585 - mape: 4.5079 - rmse: 2.0020 - ar: 0.9235 - val_loss: 4.0396 - val_mse: 4.0114 - val_mae: 1.2688 - val_mape: 1.7311 - val_rmse: 1.9670 - val_ar: 0.3428
# Epoch 2/100
# 36/36 [==============================] - 0s 7ms/step - loss: 3.5503 - mse: 3.5503 - mae: 1.2732 - mape: 2.9463 - rmse: 1.8691 - ar: 0.9141 - val_loss: 3.9588 - val_mse: 3.9326 - val_mae: 1.2555 - val_mape: 1.6736 - val_rmse: 1.9478 - val_ar: 0.3661
# Epoch 3/100
# 36/36 [==============================] - 0s 7ms/step - loss: 3.5457 - mse: 3.5457 - mae: 1.2766 - mape: 2.9774 - rmse: 1.8661 - ar: 0.9132 - val_loss: 4.0713 - val_mse: 4.0428 - val_mae: 1.2838 - val_mape: 1.6414 - val_rmse: 1.9739 - val_ar: 0.3400
# Epoch 4/100
# 36/36 [==============================] - 0s 7ms/step - loss: 3.2920 - mse: 3.2920 - mae: 1.2505 - mape: 2.8126 - rmse: 1.7954 - ar: 0.9175 - val_loss: 4.1404 - val_mse: 4.1138 - val_mae: 1.3116 - val_mape: 1.5418 - val_rmse: 1.9967 - val_ar: 0.3127
# Epoch 5/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6124 - mse: 3.6124 - mae: 1.2754 - mape: 2.3196 - rmse: 1.8832 - ar: 0.9256 - val_loss: 4.0809 - val_mse: 4.0528 - val_mae: 1.2729 - val_mape: 1.7589 - val_rmse: 1.9749 - val_ar: 0.3239
# Epoch 6/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5611 - mse: 3.5611 - mae: 1.2684 - mape: 2.8767 - rmse: 1.8745 - ar: 0.9145 - val_loss: 4.0340 - val_mse: 4.0072 - val_mae: 1.2718 - val_mape: 1.5677 - val_rmse: 1.9652 - val_ar: 0.3049
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.3739 - mse: 3.3739 - mae: 1.2644 - mape: 2.8641 - rmse: 1.8240 - ar: 0.9599 - val_loss: 4.1021 - val_mse: 4.0773 - val_mae: 1.2961 - val_mape: 1.7043 - val_rmse: 1.9834 - val_ar: 0.3103
# 4/4 [==============================] - 0s 2ms/step
# [MSE Baseline] train: 3.6673041016935772  test: 3.8851370430342125
# 4/4 [==============================] - 0s 6ms/step - loss: 4.1021 - mse: 4.0773 - mae: 1.2961 - mape: 1.7043 - rmse: 1.9834 - ar: 0.3103

# %% [markdown]
# ## SSE

# %%
data_name = data_names[1]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)

# we drop a couple of years because they have some periods were volume is zero
# we also drop some data which contain nans
dataframe = pd.read_csv(data_path)[1768:].dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)
print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
results[1] = ann.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/SSE.csv
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 7)]            0
#
#  flatten_1 (Flatten)         (None, 35)                0
#
#  dense_3 (Dense)             (None, 1000)              36000
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 1000)              0
#
#  dropout_2 (Dropout)         (None, 1000)              0
#
#  dense_4 (Dense)             (None, 100)               100100
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 100)               0
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 1)                 101
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 1)                 0
#
# =================================================================
# Total params: 136201 (532.04 KB)
# Trainable params: 136201 (532.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 23/23 [==============================] - 1s 18ms/step - loss: 3.9335 - mse: 3.9335 - mae: 1.3091 - mape: 2.1622 - rmse: 1.9554 - ar: 0.9372 - val_loss: 3.8484 - val_mse: 3.9181 - val_mae: 1.3997 - val_mape: 26.4506 - val_rmse: 1.9769 - val_ar: 0.2524
# Epoch 2/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.5755 - mse: 4.5755 - mae: 1.3503 - mape: 1.8496 - rmse: 2.1038 - ar: 1.0252 - val_loss: 3.4921 - val_mse: 3.5691 - val_mae: 1.2770 - val_mape: 31.8105 - val_rmse: 1.8869 - val_ar: 0.3186
# Epoch 3/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.1837 - mse: 4.1837 - mae: 1.2907 - mape: 1.5830 - rmse: 2.0083 - ar: 0.9616 - val_loss: 3.5333 - val_mse: 3.5815 - val_mae: 1.3048 - val_mape: 24.3666 - val_rmse: 1.8913 - val_ar: 0.3071
# Epoch 4/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.9237 - mse: 4.9237 - mae: 1.3158 - mape: 3.4963 - rmse: 2.1368 - ar: 1.0033 - val_loss: 3.4190 - val_mse: 3.4529 - val_mae: 1.2649 - val_mape: 20.1043 - val_rmse: 1.8575 - val_ar: 0.3568
# Epoch 5/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.3799 - mse: 4.3799 - mae: 1.3053 - mape: 1.8069 - rmse: 2.0259 - ar: 0.9817 - val_loss: 3.5013 - val_mse: 3.4950 - val_mae: 1.2850 - val_mape: 25.9435 - val_rmse: 1.8689 - val_ar: 0.3835
# Epoch 6/100
# 23/23 [==============================] - 0s 8ms/step - loss: 5.2034 - mse: 5.2034 - mae: 1.3688 - mape: 4.3462 - rmse: 2.2133 - ar: 1.0404 - val_loss: 3.4700 - val_mse: 3.4423 - val_mae: 1.2651 - val_mape: 35.6915 - val_rmse: 1.8546 - val_ar: 0.4382
# Epoch 7/100
# 23/23 [==============================] - 0s 8ms/step - loss: 4.0906 - mse: 4.0906 - mae: 1.2710 - mape: 2.4432 - rmse: 1.9746 - ar: 1.0163 - val_loss: 3.4879 - val_mse: 3.4977 - val_mae: 1.2656 - val_mape: 24.0876 - val_rmse: 1.8698 - val_ar: 0.3482
# Epoch 8/100
# 23/23 [==============================] - 0s 9ms/step - loss: 4.3292 - mse: 4.3292 - mae: 1.2992 - mape: 3.7333 - rmse: 2.0360 - ar: 1.0410 - val_loss: 3.5114 - val_mse: 3.4665 - val_mae: 1.2723 - val_mape: 30.6346 - val_rmse: 1.8610 - val_ar: 0.3828
# Epoch 9/100
# 23/23 [==============================] - 0s 8ms/step - loss: 3.6815 - mse: 3.6815 - mae: 1.2527 - mape: 1.7171 - rmse: 1.8928 - ar: 0.9699 - val_loss: 3.5503 - val_mse: 3.5609 - val_mae: 1.2918 - val_mape: 33.4953 - val_rmse: 1.8860 - val_ar: 0.3440
# 4/4 [==============================] - 0s 1ms/step
# [MSE Baseline] train: 4.395288376550359  test: 3.4566893566021157
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5503 - mse: 3.5609 - mae: 1.2918 - mape: 33.4953 - rmse: 1.8860 - ar: 0.3440

# %% [markdown]
# ## IBM

# %%
data_name = data_names[2]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[2] = ann.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/IBM.csv
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 5, 7)]            0
#
#  flatten_2 (Flatten)         (None, 35)                0
#
#  dense_6 (Dense)             (None, 1000)              36000
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 1000)              0
#
#  dropout_4 (Dropout)         (None, 1000)              0
#
#  dense_7 (Dense)             (None, 100)               100100
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 100)               0
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_8 (Dense)             (None, 1)                 101
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1)                 0
#
# =================================================================
# Total params: 136201 (532.04 KB)
# Trainable params: 136201 (532.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 15ms/step - loss: 4.1439 - mse: 4.1439 - mae: 1.3690 - mape: 2.0575 - rmse: 2.0103 - ar: 0.9090 - val_loss: 7.4875 - val_mse: 7.3846 - val_mae: 1.4101 - val_mape: 1.9111 - val_rmse: 2.5758 - val_ar: 0.3640
# Epoch 2/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.5809 - mse: 3.5809 - mae: 1.2952 - mape: 19.6655 - rmse: 1.8785 - ar: 0.9412 - val_loss: 7.3887 - val_mse: 7.2866 - val_mae: 1.4198 - val_mape: 1.6991 - val_rmse: 2.5577 - val_ar: 0.4002
# Epoch 3/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.0100 - mse: 5.0100 - mae: 1.3055 - mape: 2.3417 - rmse: 2.1036 - ar: 0.9707 - val_loss: 7.5296 - val_mse: 7.4245 - val_mae: 1.4134 - val_mape: 1.7833 - val_rmse: 2.5841 - val_ar: 0.3941
# Epoch 4/100
# 36/36 [==============================] - 0s 7ms/step - loss: 5.1220 - mse: 5.1220 - mae: 1.3424 - mape: inf - rmse: 2.1577 - ar: 0.9733 - val_loss: 7.3756 - val_mse: 7.2728 - val_mae: 1.3931 - val_mape: 1.8588 - val_rmse: 2.5552 - val_ar: 0.4160
# Epoch 5/100
# 36/36 [==============================] - 0s 9ms/step - loss: 4.3529 - mse: 4.3529 - mae: 1.3330 - mape: inf - rmse: 2.0304 - ar: 0.9626 - val_loss: 7.3554 - val_mse: 7.2533 - val_mae: 1.3984 - val_mape: 1.7854 - val_rmse: 2.5531 - val_ar: 0.5012
# Epoch 6/100
# 36/36 [==============================] - 0s 9ms/step - loss: 4.9271 - mse: 4.9271 - mae: 1.3384 - mape: 2091.9260 - rmse: 2.1154 - ar: 0.9962 - val_loss: 7.4617 - val_mse: 7.3581 - val_mae: 1.4205 - val_mape: 1.9363 - val_rmse: 2.5708 - val_ar: 0.3918
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.2640 - mse: 5.2640 - mae: 1.2833 - mape: inf - rmse: 2.0963 - ar: 0.9401 - val_loss: 7.3695 - val_mse: 7.2664 - val_mae: 1.3896 - val_mape: 1.7722 - val_rmse: 2.5612 - val_ar: 0.4880
# Epoch 8/100
# 36/36 [==============================] - 0s 10ms/step - loss: 4.7332 - mse: 4.7332 - mae: 1.3012 - mape: inf - rmse: 2.0386 - ar: 0.9781 - val_loss: 7.4774 - val_mse: 7.3761 - val_mae: 1.4128 - val_mape: 1.7203 - val_rmse: 2.5700 - val_ar: 0.4137
# Epoch 9/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.1649 - mse: 4.1649 - mae: 1.2972 - mape: inf - rmse: 1.9604 - ar: 0.9562 - val_loss: 7.4451 - val_mse: 7.3438 - val_mae: 1.4018 - val_mape: 1.8843 - val_rmse: 2.5672 - val_ar: 0.4123
# Epoch 10/100
# 36/36 [==============================] - 0s 9ms/step - loss: 5.2524 - mse: 5.2524 - mae: 1.3215 - mape: inf - rmse: 2.1178 - ar: 0.9583 - val_loss: 7.4214 - val_mse: 7.3182 - val_mae: 1.3975 - val_mape: 1.9200 - val_rmse: 2.5678 - val_ar: 0.3606
# 4/4 [==============================] - 0s 2ms/step
# [MSE Baseline] train: 4.199697650251511  test: 7.163597671973476
# 4/4 [==============================] - 0s 6ms/step - loss: 7.4214 - mse: 7.3182 - mae: 1.3975 - mape: 1.9200 - rmse: 2.5678 - ar: 0.3606

# %% [markdown]
# ## MSFT

# %%
data_name = data_names[3]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[3] = ann.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/MSFT.csv
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 5, 7)]            0
#
#  flatten_3 (Flatten)         (None, 35)                0
#
#  dense_9 (Dense)             (None, 1000)              36000
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 1000)              0
#
#  dropout_6 (Dropout)         (None, 1000)              0
#
#  dense_10 (Dense)            (None, 100)               100100
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 100)               0
#
#  dropout_7 (Dropout)         (None, 100)               0
#
#  dense_11 (Dense)            (None, 1)                 101
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 1)                 0
#
# =================================================================
# Total params: 136201 (532.04 KB)
# Trainable params: 136201 (532.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 14ms/step - loss: 4.1738 - mse: 4.1738 - mae: 1.3772 - mape: 1.8014 - rmse: 2.0240 - ar: 0.9421 - val_loss: 11.2005 - val_mse: 10.9779 - val_mae: 1.4221 - val_mape: 1.9168 - val_rmse: 2.8386 - val_ar: 0.3561
# Epoch 2/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.5146 - mse: 4.5146 - mae: 1.3034 - mape: 23.8423 - rmse: 2.0259 - ar: 0.9424 - val_loss: 11.2673 - val_mse: 11.0446 - val_mae: 1.4079 - val_mape: 1.7578 - val_rmse: 2.8449 - val_ar: 0.3324
# Epoch 3/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.9961 - mse: 4.9961 - mae: 1.3551 - mape: 14.7267 - rmse: 2.1489 - ar: 0.9858 - val_loss: 11.0797 - val_mse: 10.8592 - val_mae: 1.3971 - val_mape: 1.9172 - val_rmse: 2.8176 - val_ar: 0.3682
# Epoch 4/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.6441 - mse: 3.6441 - mae: 1.2882 - mape: 53.4325 - rmse: 1.8893 - ar: 0.9345 - val_loss: 11.1587 - val_mse: 10.9360 - val_mae: 1.3817 - val_mape: 1.6524 - val_rmse: 2.8225 - val_ar: 0.3757
# Epoch 5/100
# 36/36 [==============================] - 0s 9ms/step - loss: 3.8617 - mse: 3.8617 - mae: 1.2999 - mape: 1.9055 - rmse: 1.9487 - ar: 0.9634 - val_loss: 11.1911 - val_mse: 10.9665 - val_mae: 1.3975 - val_mape: 1.8548 - val_rmse: 2.8266 - val_ar: 0.3699
# Epoch 6/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8755 - mse: 3.8755 - mae: 1.2996 - mape: 40.1457 - rmse: 1.9456 - ar: 0.9492 - val_loss: 11.3073 - val_mse: 11.0846 - val_mae: 1.4250 - val_mape: 1.6320 - val_rmse: 2.8509 - val_ar: 0.3769
# Epoch 7/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.4058 - mse: 5.4058 - mae: 1.3206 - mape: 27.6414 - rmse: 2.1767 - ar: 0.9628 - val_loss: 10.6763 - val_mse: 10.4662 - val_mae: 1.4287 - val_mape: 2.1633 - val_rmse: 2.7956 - val_ar: 0.3994
# Epoch 8/100
# 36/36 [==============================] - 0s 8ms/step - loss: 5.1259 - mse: 5.1259 - mae: 1.3173 - mape: 46.4437 - rmse: 2.1151 - ar: 0.9514 - val_loss: 10.8074 - val_mse: 10.5908 - val_mae: 1.3787 - val_mape: 1.7846 - val_rmse: 2.7864 - val_ar: 0.5136
# Epoch 9/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.0681 - mse: 4.0681 - mae: 1.2928 - mape: 24.8979 - rmse: 1.9800 - ar: 0.9784 - val_loss: 10.9215 - val_mse: 10.7052 - val_mae: 1.3978 - val_mape: 1.8558 - val_rmse: 2.7996 - val_ar: 0.4877
# Epoch 10/100
# 36/36 [==============================] - 0s 8ms/step - loss: 4.1016 - mse: 4.1016 - mae: 1.3163 - mape: 1.9111 - rmse: 2.0072 - ar: 0.9674 - val_loss: 11.2111 - val_mse: 10.9872 - val_mae: 1.4233 - val_mape: 1.9983 - val_rmse: 2.8414 - val_ar: 0.4434
# Epoch 11/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.8592 - mse: 3.8592 - mae: 1.3200 - mape: 24.8706 - rmse: 1.9486 - ar: 0.9675 - val_loss: 11.0566 - val_mse: 10.8342 - val_mae: 1.4086 - val_mape: 2.0148 - val_rmse: 2.8207 - val_ar: 0.4498
# Epoch 12/100
# 36/36 [==============================] - 0s 8ms/step - loss: 3.7594 - mse: 3.7594 - mae: 1.2828 - mape: 52.6562 - rmse: 1.9170 - ar: 0.9875 - val_loss: 11.1002 - val_mse: 10.8756 - val_mae: 1.3970 - val_mape: 1.9243 - val_rmse: 2.8168 - val_ar: 0.3995
# 4/4 [==============================] - 0s 2ms/step
# [MSE Baseline] train: 5.310293081249544  test: 10.919209093531679
# 4/4 [==============================] - 0s 3ms/step - loss: 11.1002 - mse: 10.8756 - mae: 1.3970 - mape: 1.9243 - rmse: 2.8168 - ar: 0.3995

# %% [markdown]
# ## PAICC

# %%
data_name = data_names[4]
data_path="stock_market_GAN/datasets/"+data_name+".csv"
print(data_path)
dataframe = pd.read_csv(data_path).dropna()

dataframe = add_Ma(dataframe)

#plot_dataframe(dataframe)

data_gen_train, data_gen_test = get_gen_train_test(dataframe)

ann = make_ANN_model()
history = ann.fit(data_gen_train, validation_data=data_gen_test, epochs = 100, 
                   callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5))
plot_history(history)
plot_frame(*data_gen_test[0], ann)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))

results[4] = ann.evaluate(data_gen_test)
# Out:
# stock_market_GAN/datasets/PAICC.csv
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 5, 7)]            0
#
#  flatten_4 (Flatten)         (None, 35)                0
#
#  dense_12 (Dense)            (None, 1000)              36000
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 1000)              0
#
#  dropout_8 (Dropout)         (None, 1000)              0
#
#  dense_13 (Dense)            (None, 100)               100100
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 100)               0
#
#  dropout_9 (Dropout)         (None, 100)               0
#
#  dense_14 (Dense)            (None, 1)                 101
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 1)                 0
#
# =================================================================
# Total params: 136201 (532.04 KB)
# Trainable params: 136201 (532.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 15ms/step - loss: 3.6499 - mse: 3.6499 - mae: 1.2974 - mape: inf - rmse: 1.8880 - ar: 0.9459 - val_loss: 3.4586 - val_mse: 3.4656 - val_mae: 1.2812 - val_mape: 237.3306 - val_rmse: 1.8611 - val_ar: 0.3053
# Epoch 2/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4351 - mse: 3.4351 - mae: 1.2654 - mape: inf - rmse: 1.8384 - ar: 0.9598 - val_loss: 3.2535 - val_mse: 3.2514 - val_mae: 1.2264 - val_mape: 282.5944 - val_rmse: 1.8030 - val_ar: 0.3901
# Epoch 3/100
# 26/26 [==============================] - 0s 9ms/step - loss: 3.2675 - mse: 3.2675 - mae: 1.2417 - mape: inf - rmse: 1.7866 - ar: 0.9802 - val_loss: 3.3065 - val_mse: 3.3105 - val_mae: 1.2525 - val_mape: 203.8885 - val_rmse: 1.8192 - val_ar: 0.3290
# Epoch 4/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.1777 - mse: 3.1777 - mae: 1.2148 - mape: inf - rmse: 1.7600 - ar: 1.0144 - val_loss: 3.3820 - val_mse: 3.3798 - val_mae: 1.2599 - val_mape: 382.3414 - val_rmse: 1.8375 - val_ar: 0.3781
# Epoch 5/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3623 - mse: 3.3623 - mae: 1.2411 - mape: inf - rmse: 1.8198 - ar: 0.9632 - val_loss: 3.3855 - val_mse: 3.3996 - val_mae: 1.2750 - val_mape: 270.3584 - val_rmse: 1.8433 - val_ar: 0.3223
# Epoch 6/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.2811 - mse: 3.2811 - mae: 1.2192 - mape: inf - rmse: 1.7935 - ar: 0.9708 - val_loss: 3.3581 - val_mse: 3.3520 - val_mae: 1.2681 - val_mape: 278.5916 - val_rmse: 1.8303 - val_ar: 0.3840
# Epoch 7/100
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4839 - mse: 3.4839 - mae: 1.2512 - mape: inf - rmse: 1.8502 - ar: 1.0389 - val_loss: 3.5449 - val_mse: 3.5559 - val_mae: 1.3007 - val_mape: 266.6664 - val_rmse: 1.8853 - val_ar: 0.3152
# 4/4 [==============================] - 0s 2ms/step
# [MSE Baseline] train: 3.4539698920723225  test: 3.2622905110959155
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5449 - mse: 3.5559 - mae: 1.3007 - mape: 266.6664 - rmse: 1.8853 - ar: 0.3152

# %% [markdown]
# ## Results

# %%
df = pd.DataFrame(data = results, index = data_names, columns = metrics)
df.loc['mean'] = results.mean(axis=0)
df
# Out:
#              loss        mse       mae        mape      rmse        ar
# S&P500   4.102146   4.077329  1.296085    1.704270  1.983371  0.310276
# SSE      3.550327   3.560921  1.291817   33.495293  1.885996  0.344004
# IBM      7.421405   7.318249  1.397525    1.920027  2.567797  0.360639
# MSFT    11.100196  10.875622  1.397035    1.924253  2.816808  0.399489
# PAICC    3.544933   3.555938  1.300680  266.666412  1.885347  0.315172
# mean     5.943801   5.877612  1.336628   61.142051  2.227864  0.345916
